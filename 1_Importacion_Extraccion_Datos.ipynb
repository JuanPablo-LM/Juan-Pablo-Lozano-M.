# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPablo-LM/Juan-Pablo-Lozano-M./blob/main/1_Importacion_Extraccion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/3_Analisis_y_visualizacion_datos/1_Importacion_Extraccion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # 🛢️**Métodos de importación y extracción de datos**

# %% [markdown]
# En esta clase aprenderás a:
#
# - Importar y extraer datos desde diferentes fuentes:
#
#   - Archivos locales (CSV, Excel, TXT)
#   - Archivos en la web (CSV desde URL)
#   - APIs
#
# - Explorar el dataset
#
# Este es el primer paso para todo análisis de datos en economía y ciencias sociales.

# %% [markdown]
# ## Instalaciones necesarias

# %% [markdown]
# No es necesario si:
# - Instalaste los programas del archivo requirements.txt
# - Corriste el notebook "0_instalacion_librerias.ipynb"
# - Estás usando Google Colab

# %%
# Para poder leer y abrir archivos de Excel
# !pip install xlrd openpyxl
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.13/dist-packages (2.0.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.13/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.13/dist-packages (from openpyxl) (2.0.0)

# %%
# Para trabajar datos tabulares
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Mejorar visualización de los dataframes

# %%
# Que muestre todas las columnas
pd.options.display.max_columns = None
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Importar datos desde archivos CSV, Excel, TXT

# %% [markdown]
# En Google Colab hay dos opciones:
# - Subir el archivo al entorno (se borra cuando se desconecta del entorno de ejecución o se cierra el notebook)
# - Importar el archivo desde Google Drive

# %% [markdown]
# ### Subir el archivo al entorno

# %%
# Archivo csv
df_ssc = pd.read_csv('Supersociedades_2023.csv', encoding = 'utf-8', dtype = str)
df_ssc.head()
# Out:
#   RANKING        NIT                                    RAZON_SOCIAL  \
# 0       1  899999068                                   ECOPETROL S.A
# 1       2  900112515                     REFINERIA DE CARTAGENA S.A.
# 2       3  890100577  AEROVIAS DEL CONTINENTE AMERICANO S.A. AVIANCA
# 3       4  830095213                        ORGANIZACIÓN TERPEL S.A.
# 4       5  900156264           NUEVA EMPRESA PROMOTORA DE SALUD S.A.
#
#   CODIGO_DEPARTAMENTO  DEPARTAMENTO CODIGO_MUNICIPIO            MUNICIPIO  \
# 0                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 1                  13       BOLÍVAR            13001  CARTAGENA DE INDIAS
# 2                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 3                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 4                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
#
#    CIIU                                   DESCRIPCION_CIIU AÑOS_EMPRESA  \
# 0  0610                       Extracción de petróleo crudo          NaN
# 1  1921  Fabricación de productos de la refinación del ...          NaN
# 2  5111             Transporte aéreo nacional de pasajeros          NaN
# 3  4661  Comercio al por mayor de combustibles sólidos,...          NaN
# 4  8430  Actividades de planes de seguridad social de a...          NaN
#
#         ACTIVOS_2023       PASIVOS_2023   PATRIMONIO_2023  \
# 0  198732048000000.0  120339989000000.0  78392059000000.0
# 1   37080019697618.0   12339425674582.0  24740594023036.0
# 2   18938010690614.0   20044894930057.0  -1106884239443.0
# 3    7357710447000.0    4606665920000.0   2751044527000.0
# 4    6815192849000.0    6671800785000.0    143392064000.0
#
#   INGRESOS_OPERACIONALES_2023     UTILIDAD_2023       ACTIVOS_2022  \
# 0           129508675000000.0  19062091000000.0  216847696868000.0
# 1            32050663229016.0   3491071127880.0   42844949768948.0
# 2            27150513815328.0    224732589350.0   17886971237998.0
# 3            23048284871000.0    285273513000.0    7481575073000.0
# 4            20279681124000.0   -341816765000.0    5913636590000.0
#
#         PASIVOS_2022   PATRIMONIO_2022 INGRESOS_OPERACIONALES_2022  \
# 0  125812992019000.0  91034704849000.0           144820641934000.0
# 1   16480903602221.0  26364046166727.0            27910347095288.0
# 2   19333652424242.0  -1446681186244.0            22520677111772.0
# 3    4473299528000.0   3008275545000.0            23603192495000.0
# 4    5428427760000.0    485208830000.0            14777134070000.0
#
#       UTILIDAD_2022 DIRECCION TELEFONO CELULAR EMAIL       SUPERVISOR
# 0  33406291190000.0       NaN      NaN     NaN   NaN  SUPERFINANCIERA
# 1   2188258717171.0       NaN      NaN     NaN   NaN   SUPERSERVICIOS
# 2   -801213587941.0       NaN      NaN     NaN   NaN  SUPERTRANSPORTE
# 3    333411532000.0       NaN      NaN     NaN   NaN  SUPERFINANCIERA
# 4     10400284000.0       NaN      NaN     NaN   NaN       SUPERSALUD

# %%
df_ssc['ACTIVOS_2023'].dtype
# Out:
# dtype('O')

# %%
df_ssc['ACTIVOS_2023'] = df_ssc['ACTIVOS_2023'].astype('float64')
df_ssc.head()
# Out:
#   RANKING        NIT                                    RAZON_SOCIAL  \
# 0       1  899999068                                   ECOPETROL S.A
# 1       2  900112515                     REFINERIA DE CARTAGENA S.A.
# 2       3  890100577  AEROVIAS DEL CONTINENTE AMERICANO S.A. AVIANCA
# 3       4  830095213                        ORGANIZACIÓN TERPEL S.A.
# 4       5  900156264           NUEVA EMPRESA PROMOTORA DE SALUD S.A.
#
#   CODIGO_DEPARTAMENTO  DEPARTAMENTO CODIGO_MUNICIPIO            MUNICIPIO  \
# 0                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 1                  13       BOLÍVAR            13001  CARTAGENA DE INDIAS
# 2                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 3                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 4                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
#
#    CIIU                                   DESCRIPCION_CIIU AÑOS_EMPRESA  \
# 0  0610                       Extracción de petróleo crudo          NaN
# 1  1921  Fabricación de productos de la refinación del ...          NaN
# 2  5111             Transporte aéreo nacional de pasajeros          NaN
# 3  4661  Comercio al por mayor de combustibles sólidos,...          NaN
# 4  8430  Actividades de planes de seguridad social de a...          NaN
#
#             ACTIVOS_2023       PASIVOS_2023   PATRIMONIO_2023  \
# 0 198,732,048,000,000.00  120339989000000.0  78392059000000.0
# 1  37,080,019,697,618.00   12339425674582.0  24740594023036.0
# 2  18,938,010,690,614.00   20044894930057.0  -1106884239443.0
# 3   7,357,710,447,000.00    4606665920000.0   2751044527000.0
# 4   6,815,192,849,000.00    6671800785000.0    143392064000.0
#
#   INGRESOS_OPERACIONALES_2023     UTILIDAD_2023       ACTIVOS_2022  \
# 0           129508675000000.0  19062091000000.0  216847696868000.0
# 1            32050663229016.0   3491071127880.0   42844949768948.0
# 2            27150513815328.0    224732589350.0   17886971237998.0
# 3            23048284871000.0    285273513000.0    7481575073000.0
# 4            20279681124000.0   -341816765000.0    5913636590000.0
#
#         PASIVOS_2022   PATRIMONIO_2022 INGRESOS_OPERACIONALES_2022  \
# 0  125812992019000.0  91034704849000.0           144820641934000.0
# 1   16480903602221.0  26364046166727.0            27910347095288.0
# 2   19333652424242.0  -1446681186244.0            22520677111772.0
# 3    4473299528000.0   3008275545000.0            23603192495000.0
# 4    5428427760000.0    485208830000.0            14777134070000.0
#
#       UTILIDAD_2022 DIRECCION TELEFONO CELULAR EMAIL       SUPERVISOR
# 0  33406291190000.0       NaN      NaN     NaN   NaN  SUPERFINANCIERA
# 1   2188258717171.0       NaN      NaN     NaN   NaN   SUPERSERVICIOS
# 2   -801213587941.0       NaN      NaN     NaN   NaN  SUPERTRANSPORTE
# 3    333411532000.0       NaN      NaN     NaN   NaN  SUPERFINANCIERA
# 4     10400284000.0       NaN      NaN     NaN   NaN       SUPERSALUD

# %%
df_ssc['ACTIVOS_2023'].dtype
# Out:
# dtype('float64')

# %%
df_ssc['ACTIVOS_2023'] = df_ssc['ACTIVOS_2023'].astype(str)
df_ssc.head()
# Out:
#   RANKING        NIT                                    RAZON_SOCIAL  \
# 0       1  899999068                                   ECOPETROL S.A
# 1       2  900112515                     REFINERIA DE CARTAGENA S.A.
# 2       3  890100577  AEROVIAS DEL CONTINENTE AMERICANO S.A. AVIANCA
# 3       4  830095213                        ORGANIZACIÓN TERPEL S.A.
# 4       5  900156264           NUEVA EMPRESA PROMOTORA DE SALUD S.A.
#
#   CODIGO_DEPARTAMENTO  DEPARTAMENTO CODIGO_MUNICIPIO            MUNICIPIO  \
# 0                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 1                  13       BOLÍVAR            13001  CARTAGENA DE INDIAS
# 2                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 3                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
# 4                  11  BOGOTÁ, D.C.            11001         BOGOTÁ, D.C.
#
#    CIIU                                   DESCRIPCION_CIIU AÑOS_EMPRESA  \
# 0  0610                       Extracción de petróleo crudo          NaN
# 1  1921  Fabricación de productos de la refinación del ...          NaN
# 2  5111             Transporte aéreo nacional de pasajeros          NaN
# 3  4661  Comercio al por mayor de combustibles sólidos,...          NaN
# 4  8430  Actividades de planes de seguridad social de a...          NaN
#
#         ACTIVOS_2023       PASIVOS_2023   PATRIMONIO_2023  \
# 0  198732048000000.0  120339989000000.0  78392059000000.0
# 1   37080019697618.0   12339425674582.0  24740594023036.0
# 2   18938010690614.0   20044894930057.0  -1106884239443.0
# 3    7357710447000.0    4606665920000.0   2751044527000.0
# 4    6815192849000.0    6671800785000.0    143392064000.0
#
#   INGRESOS_OPERACIONALES_2023     UTILIDAD_2023       ACTIVOS_2022  \
# 0           129508675000000.0  19062091000000.0  216847696868000.0
# 1            32050663229016.0   3491071127880.0   42844949768948.0
# 2            27150513815328.0    224732589350.0   17886971237998.0
# 3            23048284871000.0    285273513000.0    7481575073000.0
# 4            20279681124000.0   -341816765000.0    5913636590000.0
#
#         PASIVOS_2022   PATRIMONIO_2022 INGRESOS_OPERACIONALES_2022  \
# 0  125812992019000.0  91034704849000.0           144820641934000.0
# 1   16480903602221.0  26364046166727.0            27910347095288.0
# 2   19333652424242.0  -1446681186244.0            22520677111772.0
# 3    4473299528000.0   3008275545000.0            23603192495000.0
# 4    5428427760000.0    485208830000.0            14777134070000.0
#
#       UTILIDAD_2022 DIRECCION TELEFONO CELULAR EMAIL       SUPERVISOR
# 0  33406291190000.0       NaN      NaN     NaN   NaN  SUPERFINANCIERA
# 1   2188258717171.0       NaN      NaN     NaN   NaN   SUPERSERVICIOS
# 2   -801213587941.0       NaN      NaN     NaN   NaN  SUPERTRANSPORTE
# 3    333411532000.0       NaN      NaN     NaN   NaN  SUPERFINANCIERA
# 4     10400284000.0       NaN      NaN     NaN   NaN       SUPERSALUD

# %%
df_ssc['ACTIVOS_2023'].dtype
# Out:
# dtype('O')

# %%
# Archivo txt
df_mun = pd.read_csv('Base_municipios.txt', sep = "|", decimal = ',', encoding = 'utf-8', converters = {'Cod. Municipio':str})
df_mun.head()
# Out:
#   Cod. Municipio Departamento   Municipio  Población municipio Subregión PDET  \
# 0          05001    Antioquia    Medellín              2572350            NaN
# 1          05002    Antioquia   Abejorral                21109            NaN
# 2          05004    Antioquia    Abriaquí                 2804            NaN
# 3          05021    Antioquia  Alejandría                 4874            NaN
# 4          05030    Antioquia       Amagá                31851            NaN
#
#    ZOMAC  Valor agregado municipio  % Act. primarias municipio  \
# 0      0                 66,432.28                        0.18
# 1      1                    314.20                       45.43
# 2      1                     38.48                       37.04
# 3      1                     67.95                       18.02
# 4      0                    635.93                        6.84
#
#    % Act. secundarias municipio  % Act. terciarias municipio  \
# 0                         20.06                        79.76
# 1                          6.37                        48.19
# 2                          6.45                        56.51
# 3                          6.89                        75.08
# 4                         46.20                        46.96
#
#    % pobl. con educación media municipio  \
# 0                                  26.54
# 1                                  12.80
# 2                                  21.40
# 3                                  14.64
# 4                                  22.83
#
#    % pobl. con edu. técnica/tecnología municipio  \
# 0                                          10.34
# 1                                           2.46
# 2                                           4.96
# 3                                           5.57
# 4                                           5.97
#
#    % pobl. con pregrado municipio  % pobl. con posgrado municipio  \
# 0                           11.83                            3.47
# 1                            1.73                            0.85
# 2                            2.69                            1.07
# 3                            2.92                            0.73
# 4                            2.95                            0.70
#
#    % pobreza municipio  % informalidad municipio  % mujeres municipio  \
# 0                12.80                     71.00                52.91
# 1                40.60                     87.50                47.79
# 2                34.80                     87.60                45.79
# 3                31.90                     87.10                50.39
# 4                22.90                     69.50                50.92
#
#    % jóvenes municipio  % pobl. con discapacidad municipio  \
# 0                24.48                                6.27
# 1                20.51                               16.05
# 2                22.04                               16.72
# 3                20.11                                8.10
# 4                23.26                                9.02
#
#    % grupos étnicos municipio  % pobl. campesina municipio  \
# 0                        2.59                         1.90
# 1                        0.36                          NaN
# 2                        2.04                          NaN
# 3                        0.31                          NaN
# 4                        0.52                          NaN
#
#    % pobl. LGBT municipio
# 0                    1.74
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
df_mun2 = pd.read_csv('Base_municipios.txt', sep="|", decimal=',', encoding ='utf-8')
df_mun2.head()
# Out:
#    Cod. Municipio Departamento   Municipio  Población municipio  \
# 0            5001    Antioquia    Medellín              2572350
# 1            5002    Antioquia   Abejorral                21109
# 2            5004    Antioquia    Abriaquí                 2804
# 3            5021    Antioquia  Alejandría                 4874
# 4            5030    Antioquia       Amagá                31851
#
#   Subregión PDET  ZOMAC  Valor agregado municipio  % Act. primarias municipio  \
# 0            NaN      0                 66,432.28                        0.18
# 1            NaN      1                    314.20                       45.43
# 2            NaN      1                     38.48                       37.04
# 3            NaN      1                     67.95                       18.02
# 4            NaN      0                    635.93                        6.84
#
#    % Act. secundarias municipio  % Act. terciarias municipio  \
# 0                         20.06                        79.76
# 1                          6.37                        48.19
# 2                          6.45                        56.51
# 3                          6.89                        75.08
# 4                         46.20                        46.96
#
#    % pobl. con educación media municipio  \
# 0                                  26.54
# 1                                  12.80
# 2                                  21.40
# 3                                  14.64
# 4                                  22.83
#
#    % pobl. con edu. técnica/tecnología municipio  \
# 0                                          10.34
# 1                                           2.46
# 2                                           4.96
# 3                                           5.57
# 4                                           5.97
#
#    % pobl. con pregrado municipio  % pobl. con posgrado municipio  \
# 0                           11.83                            3.47
# 1                            1.73                            0.85
# 2                            2.69                            1.07
# 3                            2.92                            0.73
# 4                            2.95                            0.70
#
#    % pobreza municipio  % informalidad municipio  % mujeres municipio  \
# 0                12.80                     71.00                52.91
# 1                40.60                     87.50                47.79
# 2                34.80                     87.60                45.79
# 3                31.90                     87.10                50.39
# 4                22.90                     69.50                50.92
#
#    % jóvenes municipio  % pobl. con discapacidad municipio  \
# 0                24.48                                6.27
# 1                20.51                               16.05
# 2                22.04                               16.72
# 3                20.11                                8.10
# 4                23.26                                9.02
#
#    % grupos étnicos municipio  % pobl. campesina municipio  \
# 0                        2.59                         1.90
# 1                        0.36                          NaN
# 2                        2.04                          NaN
# 3                        0.31                          NaN
# 4                        0.52                          NaN
#
#    % pobl. LGBT municipio
# 0                    1.74
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
# Archivo Excel
df_divipola_depto = pd.read_excel("2025-01-14 DIVIPOLA.xlsx", sheet_name = "Departamentos", skiprows = 9)
df_divipola_depto.head()
# Out:
#   Código        Nombre
# 0     05     ANTIOQUIA
# 1     08     ATLÁNTICO
# 2     11  BOGOTÁ, D.C.
# 3     13       BOLÍVAR
# 4     15        BOYACÁ

# %%
# Archivo Excel
df_divipola_mun = pd.read_excel("2025-01-14 DIVIPOLA.xlsx", sheet_name = "Municipios", skiprows = 10, dtype = str)
df_divipola_mun.head()
# Out:
#   Código      Nombre Código .1    Nombre.1 Unnamed: 4  \
# 0      05  ANTIOQUIA     05001    MEDELLÍN  Municipio
# 1      05  ANTIOQUIA     05002   ABEJORRAL  Municipio
# 2      05  ANTIOQUIA     05004    ABRIAQUÍ  Municipio
# 3      05  ANTIOQUIA     05021  ALEJANDRÍA  Municipio
# 4      05  ANTIOQUIA     05030       AMAGÁ  Municipio
#
#                                Unnamed: 5
# 0  ÁREA METROPOLITANA DEL VALLE DE ABURRÁ
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN

# %%
# Renombrar las columnas
df_divipola_mun.rename(columns={'Código':'Cod. Depto',
                                'Nombre': 'Departamento',
                                'Código .1':'Cod. Municipio',
                                'Nombre.1': 'Municipio',
                                'Unnamed: 4': 'Tipo',
                                'Unnamed: 5': 'Area Metropolitana'},
                       inplace=True)
df_divipola_mun.head(6)
# Out:
#   Código  Departamento Cod. Municipio   Municipio       Tipo  \
# 0      05    ANTIOQUIA          05001    MEDELLÍN  Municipio
# 1      05    ANTIOQUIA          05002   ABEJORRAL  Municipio
# 2      05    ANTIOQUIA          05004    ABRIAQUÍ  Municipio
# 3      05    ANTIOQUIA          05021  ALEJANDRÍA  Municipio
# 4      05    ANTIOQUIA          05030       AMAGÁ  Municipio
# 5      05    ANTIOQUIA          05031      AMALFI  Municipio
#
#                        Area Metropolitana
# 0  ÁREA METROPOLITANA DEL VALLE DE ABURRÁ
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN

# %% [markdown]
# ### Importar el archivo desde Google Drive

# %%
import os

# %% [markdown]
# 📌 Librería `os` en Python – Comandos más usados
#
# La librería "os" conecta Python con el sistema operativo para manipular archivos, directorios y configuraciones.
#
# | Comando | Descripción | Ejemplo |
# |---------|-------------|---------|
# | `os.getcwd()` | Devuelve el directorio de trabajo actual. | `os.getcwd()` |
# | `os.listdir(ruta)` | Lista los archivos y carpetas de una ruta. | `os.listdir(".")` |
# | `os.chdir(ruta)` | Cambia el directorio de trabajo. | `os.chdir("C:/Users")` |
# | `os.mkdir(nombre)` | Crea una nueva carpeta. | `os.mkdir("datos")` |
# | `os.makedirs(ruta)` | Crea carpetas anidadas. | `os.makedirs("carpeta1/carpeta2")` |
# | `os.remove(archivo)` | Elimina un archivo. | `os.remove("archivo.txt")` |
# | `os.rmdir(carpeta)` | Elimina una carpeta vacía. | `os.rmdir("datos")` |
# | `os.rename(src, dst)` | Renombra o mueve un archivo/carpeta. | `os.rename("a.txt","b.txt")` |
# | `os.path.exists(ruta)` | Verifica si una ruta existe. | `os.path.exists("datos")` |
# | `os.path.join(a, b)` | Une rutas de forma segura. | `os.path.join("carpeta", "archivo.csv")` |
#
#
# ⚠️ **Nota:**
# `os.remove` y `os.rmdir` no envían a la papelera, eliminan de forma permanente.

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Para establecer el directorio de los archivos
os.chdir('/content/drive/MyDrive/Curso_IA_20262')

# %%
df_mun_drive = pd.read_csv('Base_municipios.txt', sep="|", decimal=',', encoding ='utf-8', converters={'Cod. Municipio':str})
df_mun_drive.head()
# Out:
#   Cod. Municipio Departamento   Municipio  Población municipio Subregión PDET  \
# 0          05001    Antioquia    Medellín              2572350            NaN
# 1          05002    Antioquia   Abejorral                21109            NaN
# 2          05004    Antioquia    Abriaquí                 2804            NaN
# 3          05021    Antioquia  Alejandría                 4874            NaN
# 4          05030    Antioquia       Amagá                31851            NaN
#
#    ZOMAC  Valor agregado municipio  % Act. primarias municipio  \
# 0      0                 66,432.28                        0.18
# 1      1                    314.20                       45.43
# 2      1                     38.48                       37.04
# 3      1                     67.95                       18.02
# 4      0                    635.93                        6.84
#
#    % Act. secundarias municipio  % Act. terciarias municipio  \
# 0                         20.06                        79.76
# 1                          6.37                        48.19
# 2                          6.45                        56.51
# 3                          6.89                        75.08
# 4                         46.20                        46.96
#
#    % pobl. con educación media municipio  \
# 0                                  26.54
# 1                                  12.80
# 2                                  21.40
# 3                                  14.64
# 4                                  22.83
#
#    % pobl. con edu. técnica/tecnología municipio  \
# 0                                          10.34
# 1                                           2.46
# 2                                           4.96
# 3                                           5.57
# 4                                           5.97
#
#    % pobl. con pregrado municipio  % pobl. con posgrado municipio  \
# 0                           11.83                            3.47
# 1                            1.73                            0.85
# 2                            2.69                            1.07
# 3                            2.92                            0.73
# 4                            2.95                            0.70
#
#    % pobreza municipio  % informalidad municipio  % mujeres municipio  \
# 0                12.80                     71.00                52.91
# 1                40.60                     87.50                47.79
# 2                34.80                     87.60                45.79
# 3                31.90                     87.10                50.39
# 4                22.90                     69.50                50.92
#
#    % jóvenes municipio  % pobl. con discapacidad municipio  \
# 0                24.48                                6.27
# 1                20.51                               16.05
# 2                22.04                               16.72
# 3                20.11                                8.10
# 4                23.26                                9.02
#
#    % grupos étnicos municipio  % pobl. campesina municipio  \
# 0                        2.59                         1.90
# 1                        0.36                          NaN
# 2                        2.04                          NaN
# 3                        0.31                          NaN
# 4                        0.52                          NaN
#
#    % pobl. LGBT municipio
# 0                    1.74
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
# ## Importar datos desde una URL

# %%
# CSV desde URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df_url = pd.read_csv(url)
df_url.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0          5.10         3.50          1.40         0.20  setosa
# 1          4.90         3.00          1.40         0.20  setosa
# 2          4.70         3.20          1.30         0.20  setosa
# 3          4.60         3.10          1.50         0.20  setosa
# 4          5.00         3.60          1.40         0.20  setosa

# %% [markdown]
# ## Conectarse a una API

# %% [markdown]
# - API significa Application Programming Interface o Interfaz de Programación de Aplicaciones.
#
# - Es un conjunto de reglas y herramientas que permite que dos aplicaciones se comuniquen entre sí.
#
# - Una aplicación expone sus funcionalidades o datos a través de la API.
#
# - Otra aplicación puede usarlos, sin necesidad de saber cómo funciona internamente.
#
# - Una API es como un puente que permite a diferentes programas hablar entre sí y compartir información de manera segura y estandarizada.

# %% [markdown]
# ### Conexión a datos del Banco Mundial (usando wbdata)
#
# El Banco Mundial tiene una API que expone datos de desarrollo económico y social. En Python podemos usar la librería **wbdata**.
#
# Documentación: https://wbdata.readthedocs.io/en/stable/
#
# También se puede utilizar: **wbgapi**
#
# Documentación: https://pypi.org/project/wbgapi/

# %%
# !pip install wbdata
# Out:
# Requirement already satisfied: wbdata in /usr/local/lib/python3.13/dist-packages (1.1.0)
# Requirement already satisfied: appdirs<2,>=1.4 in /usr/local/lib/python3.13/dist-packages (from wbdata) (1.4.4)
# Requirement already satisfied: backoff<3,>=2.2.1 in /usr/local/lib/python3.13/dist-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6,>=5.3.2 in /usr/local/lib/python3.13/dist-packages (from wbdata) (5.5.2)
# Requirement already satisfied: dateparser<2,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from wbdata) (1.4.2)
# Requirement already satisfied: decorator<6,>=5.1.1 in /usr/local/lib/python3.13/dist-packages (from wbdata) (5.3.1)
# Requirement already satisfied: requests<3,>=2.0 in /usr/local/lib/python3.13/dist-packages (from wbdata) (2.32.4)
# Requirement already satisfied: shelved-cache<0.4,>=0.3.1 in /usr/local/lib/python3.13/dist-packages (from wbdata) (0.3.1)
# Requirement already satisfied: tabulate<1,>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from wbdata) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.13/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.13/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.13/dist-packages (from dateparser<2,>=1.2.0->wbdata) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.13/dist-packages (from dateparser<2,>=1.2.0->wbdata) (5.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0->wbdata) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0->wbdata) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0->wbdata) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0->wbdata) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)

# %%
import wbdata
import datetime

# %% [markdown]
# Nota: "datetime" permite trabajar con fechas y horas.
#
# - Obtener la fecha y hora actual.
# - Crear objetos de fecha (año, mes, día).
# - Realizar operaciones con fechas (sumar o restar días, calcular diferencias).
# - Dar formato a fechas (por ejemplo, mostrar como "31-08-2025" en lugar de "2025-08-31").
#
# El constructor datetime.datetime() acepta argumentos de fecha y hora en el siguiente orden:
#
# datetime.datetime(year, month, day, hour=0, minute=0, second=0, microsecond=0)
#
# hour: Hora (0-23)
#
# minute: Minuto (0-59)
#
# second: Segundo (0-59)
#
# microsecond: Microsegundo (0-999999)
#
# Si no se especifica la hora, minuto o segundo, Python los establecerá en 0 por defecto.

# %% [markdown]
# Vamos a traer el PIB per cápita de Colombia entre 2010 y 2023 directamente desde el Banco Mundial.

# %%
# Indicador: PIB per cápita (en USD actuales)
# País: Colombia (COL)
indicador = {"NY.GDP.PCAP.CD": "PIB per cápita"}

# El orden es: año (2010), mes (1), día (1)
fecha_inicio = datetime.datetime(2010, 1, 1)
# El orden es: año (2023), mes (1), día (1)
fecha_fin = datetime.datetime(2023, 1, 1)

# Descargar datos
df = wbdata.get_dataframe(indicador, country="COL", date=(fecha_inicio, fecha_fin))

df
# Out:
#       PIB per cápita
# date
# 2023        7,012.49
# 2022        6,680.45
# 2021        6,222.62
# 2020        5,339.69
# 2019        6,472.55
# 2018        6,816.97
# 2017        6,479.53
# 2016        5,959.84
# 2015        6,248.51
# 2014        8,187.21
# 2013        8,279.10
# 2012        8,108.60
# 2011        7,400.99
# 2010        6,398.30

# %% [markdown]
# ### Conexión a datos abiertos de Colombia
#
# https://www.datos.gov.co/

# %% [markdown]
# #### Ejemplos

# %% [markdown]
# 1. MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR, BÁSICA Y MEDIA_POR_DEPARTAMENTO
#
# https://www.datos.gov.co/Educaci-n/MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR-B-SICA/ji8i-4anb/about_data
#
# Ir a Exportar --> API de acceso y copiar el endpoint solamente.

# %%
import requests

# %% [markdown]
# "requests" es una librería que permite hacer peticiones HTTP (GET, POST, PUT, DELETE) de manera sencilla.
#
# GET → traer datos desde una página o API.
#
# POST → enviar datos a un servidor.

# %%
url = "https://www.datos.gov.co/resource/ji8i-4anb.json"

# Solicitud a la API
response = requests.get(url)
data = response.json()

# Convertir a DataFrame
df = pd.DataFrame(data)
df.head()
# Out:
#     ano c_digo_departamento  departamento poblacion_5_16  \
# 0  2011                   5     Antioquia        1288473
# 1  2011                   8     Atlántico         523935
# 2  2011                  11  Bogotá, D.C.        1479334
# 3  2011                  13       Bolívar         496676
# 4  2011                  15        Boyacá         300501
#
#   tasa_matriculacion_5_16 cobertura_neta cobertura_neta_transicion  \
# 0                   94.01          93.85                     70.28
# 1                   99.32          99.05                     50.59
# 2                    90.7          90.29                     68.63
# 3                   91.57           91.4                     59.74
# 4                   86.16          86.11                     63.36
#
#   cobertura_neta_primaria cobertura_neta_secundaria cobertura_neta_media  \
# 0                   94.12                     75.68                44.37
# 1                   98.93                     80.22                50.17
# 2                   86.99                      84.7                55.01
# 3                   90.81                     67.34                39.17
# 4                    82.5                     74.65                49.09
#
#   cobertura_bruta cobertura_bruta_transicion cobertura_bruta_primaria  \
# 0          106.81                      85.69                    117.5
# 1          107.88                      84.19                   120.41
# 2           97.78                      82.04                    97.94
# 3          110.41                      98.82                   126.45
# 4          104.15                      78.87                    99.88
#
#   cobertura_bruta_secundaria cobertura_bruta_media tamano_promedio_grupo  \
# 0                     110.81                 84.06                 27.47
# 1                     107.89                 87.98                 24.42
# 2                     106.48                 87.76                 26.75
# 3                     108.15                 80.64                  20.8
# 4                     119.78                 94.76                 22.77
#
#   sedes_conectadas_a_internet desercion desercion_transicion  \
# 0                       74.48      3.97                 3.62
# 1                       80.46      2.76                  2.6
# 2                       94.21      3.95                10.05
# 3                       30.12      3.14                 1.85
# 4                       25.26      3.07                  2.4
#
#   desercion_primaria desercion_secundaria desercion_media aprobacion  \
# 0               3.65                 4.57            3.71      93.98
# 1               3.06                 2.42            2.61       96.7
# 2                5.3                 1.96            2.55      96.05
# 3               2.93                 3.79            3.13      94.76
# 4               2.24                 4.03            3.51       94.2
#
#   aprobacion_transicion aprobacion_primaria aprobacion_secundaria  \
# 0                  0.07               94.56                  4.57
# 1                  0.12               96.49                  2.42
# 2                     0               94.69                  1.96
# 3                  0.46               95.48                  3.79
# 4                  0.17                96.1                  4.03
#
#   aprobacion_media reprobacion reprobacion_transicion reprobacion_primaria  \
# 0            93.33        2.06                   0.07                94.56
# 1            96.64        0.54                   0.12                96.49
# 2            97.45           0                      0                94.69
# 3             93.2         2.1                   0.46                95.48
# 4            93.23        2.73                   0.17                 96.1
#
#   reprobacion_secundaria reprobacion_media repitencia repitencia_transicion  \
# 0                   2.54              2.96       4.25                  0.07
# 1                   0.67              0.75       1.82                  0.12
# 2                      0                 0       3.23                     0
# 3                   2.75              3.67       4.43                  0.46
# 4                   4.31              3.26       2.62                  0.17
#
#   repitencia_primaria repitencia_secundaria repitencia_media
# 0                4.56                  5.27             1.68
# 1                1.77                  2.18             0.88
# 2                 2.3                  5.11             2.57
# 3                4.44                  5.37             2.28
# 4                 1.9                  4.19             1.55

# %% [markdown]
# 2. Casos positivos de COVID-19 en Colombia

# %%
url = "https://www.datos.gov.co/resource/gt2j-8ykr.json"

# Solicitud a la API
response = requests.get(url)
data = response.json()

# Convertir a DataFrame
df = pd.DataFrame(data)

df.head()
# Out:
#      fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0  2020-12-24 00:00:00    1556979   2020-12-22 00:00:00           76
# 1  2020-12-24 00:00:00    1556980   2020-12-19 00:00:00           76
# 2  2020-12-24 00:00:00    1556981   2020-12-19 00:00:00           76
# 3  2020-12-24 00:00:00    1556982   2020-12-22 00:00:00           76
# 4  2020-12-24 00:00:00    1556983   2020-12-22 00:00:00           76
#
#   departamento_nom ciudad_municipio ciudad_municipio_nom edad unidad_medida  \
# 0            VALLE            76001                 CALI   67             1
# 1            VALLE            76001                 CALI   66             1
# 2            VALLE            76001                 CALI   68             1
# 3            VALLE            76001                 CALI   74             1
# 4            VALLE            76001                 CALI   65             1
#
#   sexo fuente_tipo_contagio  ubicacion     estado  recuperado  \
# 0    F          Comunitaria       Casa       Leve  Recuperado
# 1    F          Comunitaria       Casa       Leve  Recuperado
# 2    F          Comunitaria       Casa       Leve  Recuperado
# 3    F          Comunitaria  Fallecido  Fallecido   Fallecido
# 4    F          Comunitaria       Casa       Leve  Recuperado
#
#   fecha_inicio_sintomas    fecha_diagnostico     fecha_recuperado  \
# 0   2020-12-21 00:00:00  2020-12-23 00:00:00  2021-01-04 00:00:00
# 1   2020-12-07 00:00:00  2020-12-23 00:00:00  2020-12-25 00:00:00
# 2   2020-12-18 00:00:00  2020-12-22 00:00:00  2021-01-01 00:00:00
# 3   2020-12-17 00:00:00  2020-12-23 00:00:00                  NaN
# 4   2020-12-21 00:00:00  2020-12-23 00:00:00  2021-01-04 00:00:00
#
#   tipo_recuperacion per_etn_         fecha_muerte nom_grupo_
# 0            Tiempo        6                  NaN        NaN
# 1            Tiempo        6                  NaN        NaN
# 2            Tiempo        6                  NaN        NaN
# 3               NaN        6  2020-12-30 00:00:00        NaN
# 4            Tiempo        6                  NaN        NaN

# %% [markdown]
# ## Explorar el dataset

# %%
df

# %%
df.head()

# %%
df.head(10)

# %%
df.sample()

# %%
# Para ver todas las filas, pero seleccionar ciertas columnas
# Opción 1
df.loc[:,['departamento_nom','edad','fecha_inicio_sintomas']]

# %%
df.loc

# %%
# Opción 2: solo seleccionar las columnas que quiero ver
df[['departamento_nom','edad','fecha_inicio_sintomas']]

# %%
# Puedo crear un nuevo dataframe con las columnas que necesito solamente
df2 = df[['departamento_nom','edad','fecha_inicio_sintomas']].copy()
df2

# %%
# Ver el nombre de todas las columnas

# %%
df2.columns

# %%
# Ver los tipos de datos de cada columna

# %%
# Ver la cantidad de filas del df
len(df2)

# %%
# Ver la cantidad de filas y columnas del df

# %%
# Ver la cantidad de filas y columnas, el nombre todas las columnas, el tipo de datos y si tiene nulos
